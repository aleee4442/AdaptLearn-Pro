# %% [markdown]
# <a href="https://colab.research.google.com/github/aleee4442/AdaptLearn-Pro/blob/main/desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imorts
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
import seaborn as sns

# %%
# importar libreria
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1606205669.py in <cell line: 0>()
# ----> 1 (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
#
# NameError: name 'keras' is not defined
